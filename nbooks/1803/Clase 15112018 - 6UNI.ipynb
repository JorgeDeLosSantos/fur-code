# %%
from rkd.didactic import *

# %%
t1,t3,t6
# Out:
# (\theta₁, \theta₃, \theta₆)

# %%
a1,a6
# Out:
# (a₁, a₆)

# %%
d1, d2, d3
# Out:
# (d₁, d₂, d₃)

# %%
l1, l6
# Out:
# (l₁, l₆)

# %%
rotz(t1)
# Out:
# ⎡cos(\theta₁)  -sin(\theta₁)  0⎤
# ⎢                              ⎥
# ⎢sin(\theta₁)  cos(\theta₁)   0⎥
# ⎢                              ⎥
# ⎣     0              0        1⎦

# %%
rotx(t2)
# Out:
# ⎡1       0              0      ⎤
# ⎢                              ⎥
# ⎢0  cos(\theta₂)  -sin(\theta₂)⎥
# ⎢                              ⎥
# ⎣0  sin(\theta₂)  cos(\theta₂) ⎦

# %%
roty(t3)
# Out:
# ⎡cos(\theta₃)   0  sin(\theta₃)⎤
# ⎢                              ⎥
# ⎢      0        1       0      ⎥
# ⎢                              ⎥
# ⎣-sin(\theta₃)  0  cos(\theta₃)⎦

# %%
rotz(45, deg=True)
# Out:
# ⎡0.707106781186548  -0.707106781186547  0⎤
# ⎢                                        ⎥
# ⎢0.707106781186547  0.707106781186548   0⎥
# ⎢                                        ⎥
# ⎣        0                  0           1⎦

# %%
rotz(pi/4).evalf()
# Out:
# ⎡0.707106781186548  -0.707106781186548   0 ⎤
# ⎢                                          ⎥
# ⎢0.707106781186548  0.707106781186548    0 ⎥
# ⎢                                          ⎥
# ⎣        0                  0           1.0⎦

# %%
htmrot(pi/4, "z")*htmrot(pi/4, "x")
# Out:
# ⎡√2               ⎤
# ⎢──  -1/2  1/2   0⎥
# ⎢2                ⎥
# ⎢                 ⎥
# ⎢√2               ⎥
# ⎢──  1/2   -1/2  0⎥
# ⎢2                ⎥
# ⎢                 ⎥
# ⎢     √2    √2    ⎥
# ⎢0    ──    ──   0⎥
# ⎢     2     2     ⎥
# ⎢                 ⎥
# ⎣0    0     0    1⎦

# %%
htmtra([10,20,0])
# Out:
# ⎡1  0  0  10⎤
# ⎢           ⎥
# ⎢0  1  0  20⎥
# ⎢           ⎥
# ⎢0  0  1  0 ⎥
# ⎢           ⎥
# ⎣0  0  0  1 ⎦

# %%
r = Robot( (l1,0,0,t1), (l2,0,0,t2) )

# %%
r.T.subs({l1: 100, l2:100, t1: pi/2, t2: pi/2})
# Out:
# ⎡-1  0   0  -100⎤
# ⎢               ⎥
# ⎢0   -1  0  100 ⎥
# ⎢               ⎥
# ⎢0   0   1   0  ⎥
# ⎢               ⎥
# ⎣0   0   0   1  ⎦

# %%
# %matplotlib nbagg

r.plot_diagram({l1: 100, l2:100, t1: 0, t2: pi/2})
# Out:
# <img src="data:image/png;base64,..." width="413.7142857142857">
